# %% [markdown]
# <a href="https://colab.research.google.com/github/niharika-naidu4/Exploratory-Data-Analysis-EDA-/blob/main/EDA_DataCoSuppyChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(r'/content/DataCoSupplyChainDataset.csv', encoding='latin-1')
print(df)
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
fil=(df['Order Country']=='India')&(df['Order Status']=='PENDING')
dict(df.loc[fil]['Order City'].value_counts())
# Out:
# {'Kanpur': 25,
#  'Pune': 24,
#  'Bangalore': 24,
#  'Lucknow': 21,
#  'Mumbai': 18,
#  'Delhi': 18,
#  'Hyderabad': 17,
#  'Ajmer': 17,
#  'Visakhapatnam': 15,
#  'Korba': 14,
#  'Nagpur': 13,
#  'Gorakhpur': 12,
#  'Chennai': 12,
#  'Jabalpur': 11,
#  'Durgapur': 11,
#  'Faridabad': 10,
#  'Jaipur': 9,
#  'Darbhanga': 9,
#  'Belgaum': 8,
#  'Guwahati': 8,
#  'Kulti': 8,
#  'Raipur': 8,
#  'Surat': 7,
#  'Agra': 7,
#  'Salem': 7,
#  'Kota': 7,
#  'Patna': 7,
#  'Jodhpur': 7,
#  'Bellary': 6,
#  'Nasik': 6,
#  'Dewas': 6,
#  'Amritsar': 6,
#  'Bhubaneswar': 6,
#  'Ulhasnagar': 5,
#  'Bokaro': 5,
#  'Satna': 5,
#  'Coimbatore': 5,
#  'Ujjain': 5,
#  'Tirunelveli': 5,
#  'Ranchi': 5,
#  'Rohtak': 5,
#  'Imphal': 5,
#  'Moradabad': 5,
#  'Jhansi': 4,
#  'Durg': 4,
#  'Malegaon': 4,
#  'Mysore': 4,
#  'Aligarh': 4,
#  'Saharanpur': 4,
#  'Srinagar': 4,
#  'Solapur': 3,
#  'Bhiwandi': 3,
#  'Anantapur': 3,
#  'Kollam': 3,
#  'Bhavnagar': 3,
#  'Kolhapur': 3,
#  'Parbhani': 3,
# ...

# %%
filt=df.loc[(df['Order Country']=='India')&(df['Order Status']=='PENDING')]
index = filt.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 537

# %%
filt=df['Order Status']=='SUSPECTED_FRAUD'
df.loc[filt]['Order Country'].value_counts().head(1)
# Out:
# Order Country
# Estados Unidos    573
# Name: count, dtype: int64

# %%
df[df['Order Item Discount']==df['Order Item Discount'].max()]
# Out:
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 12606  DEBIT                         4                              4
#
#        Benefit per order  Sales per customer   Delivery Status  \
# 12606               45.0          1499.98999  Shipping on time
#
#        Late_delivery_risk  Category Id      Category Name Customer City  ...  \
# 12606                   0           10  Strength Training        Caguas  ...
#
#       Order Zipcode Product Card Id Product Category Id  Product Description  \
# 12606           NaN             208                  10                  NaN
#
#                                            Product Image         Product Name  \
# 12606  http://images.acmesports.sports/SOLE+E35+Ellip...  SOLE E35 Elliptical
#
#       Product Price Product Status shipping date (DateOrders)   Shipping Mode
# 12606    1999.98999              0            10/3/2017 21:22  Standard Class
#
# [1 rows x 53 columns]

# %%
df['year'] = df['order date (DateOrders)'].str.slice(6,10)

# %%
Sales=df[df['Product Name'].str.contains(r'Nike(?!$)')]

# %%
dict(Sales)
# Out:
# {'Type': 50         PAYMENT
#  52         PAYMENT
#  53         PAYMENT
#  54         PAYMENT
#  59         PAYMENT
#              ...
#  179604    TRANSFER
#  179605    TRANSFER
#  179606    TRANSFER
#  179607    TRANSFER
#  179608    TRANSFER
#  Name: Type, Length: 57309, dtype: object,
#  'Days for shipping (real)': 50        6
#  52        3
#  53        5
#  54        6
#  59        2
#           ..
#  179604    5
#  179605    2
#  179606    3
#  179607    5
#  179608    4
#  Name: Days for shipping (real), Length: 57309, dtype: int64,
#  'Days for shipment (scheduled)': 50        2
#  52        2
#  53        2
#  54        2
#  59        2
#           ..
#  179604    4
#  179605    4
#  179606    4
#  179607    4
#  179608    4
#  Name: Days for shipment (scheduled), Length: 57309, dtype: int64,
#  'Benefit per order': 50         33.599998
#  52          9.100000
#  53        -21.750000
#  54          6.150000
#  59       -184.779999
#               ...
# ...

# %%
Sales.groupby('year')['Sales'].sum().tail(1)
# Out:
# year
# 2016    635886.428063
# Name: Sales, dtype: float64

# %%
filt=df['Delivery Status']=='Advance shipping'
df.loc[filt]['Delivery Status'].value_counts()
# Out:
# Delivery Status
# Advance shipping    41592
# Name: count, dtype: int64
